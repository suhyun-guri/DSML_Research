# %% [markdown]
# **각 Top Features만을 사용한 RandomForestClassifier와 LSTM의 성능 비교**

# %%
import numpy as np, os
import pandas as pd

import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

import warnings
warnings.filterwarnings(action='ignore')

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.layers import Dropout, InputLayer
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

print(tf.__version__)
print(keras.__version__)

#한글설정
import matplotlib.font_manager as fm

font_dirs = ['/usr/share/fonts/truetype/nanum', ]
font_files = fm.findSystemFonts(fontpaths=font_dirs)

for font_file in font_files:
    fm.fontManager.addfont(font_file)
    
# 한글 출력을 위해서 폰트 옵션을 설정합니다.
# "axes.unicode_minus" : 마이너스가 깨질 것을 방지

sns.set(font="NanumBarunGothic", 
        rc={"axes.unicode_minus":False},
        style='darkgrid')
# Out:
# 2.5.0
# 2.5.0

# %% [markdown]
# # RandomForest FI Top10 list
# 1. Feature Importance를 구하여 Top Features 추출
# 2. Top Features만을 사용한 데이터로 RandomForestClassifier 학습 후 정확도 측정

# %%
COLS = list(pd.read_csv('/project/LSH/total_data_7727.csv')['ITEMID'].sort_values().unique())

# %%
import random
random.seed(42)
path = '/project/LSH/'
x =  np.load(path + 'x_(7727,4068).npy')
y = np.load(path + 'y_(7727,1).npy')

# %%
x.shape
# Out:
# (7727, 4068)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics 
np.random.seed(42)
model = RandomForestClassifier()
model.fit(x, y)

pred = model.predict(x)

print(f'정확도 : {metrics.accuracy_score(y, pred)}')
# Out:
# 정확도 : 1.0

# %%
importances = model.feature_importances_
importances
# Out:
# array([1.40546352e-03, 8.98727598e-04, 3.07665371e-03, ...,
#        3.64771738e-04, 9.96495876e-05, 4.21937811e-05])

# %%
result = []
for f in range(x.shape[1]):
    result.append({'feature' : COLS[f], 'importances' : importances[f]})

# %%
rf_fi = pd.DataFrame(result).sort_values('importances', ascending=False)
rf_fi
# Out:
#           feature  importances
# 206         51277     0.013739
# 121         51006     0.009766
# 56          50912     0.009121
# 103         50983     0.007452
# 20          50862     0.007445
# ...           ...          ...
# 2281    472120006     0.000000
# 1604    131541070     0.000000
# 3217  51079079420     0.000000
# 1042     62401002     0.000000
# 3339  53169010260     0.000000
#
# [4068 rows x 2 columns]

# %%
rf_feature = rf_fi.feature[:30].to_list()
rf_feature
# Out:
# [51277,
#  51006,
#  50912,
#  50983,
#  50862,
#  63323026201,
#  51003,
#  904224461,
#  50882,
#  50868,
#  51275,
#  50813,
#  227194,
#  51244,
#  409606211,
#  51274,
#  50971,
#  245004101,
#  51256,
#  51079000220,
#  51493,
#  55390000401,
#  50960,
#  50902,
#  51265,
#  51248,
#  224275,
#  51249,
#  50893,
#  50970]

# %%
#COLS에서의 index 추출 (COLS의 index가 곧 3차원데이터 feature의 index이기 때문)

rf_feature_index = [COLS.index(i) for i in rf_feature]
rf_feature_index
# Out:
# [206,
#  121,
#  56,
#  103,
#  20,
#  3832,
#  119,
#  2611,
#  34,
#  26,
#  204,
#  8,
#  383,
#  184,
#  2195,
#  203,
#  95,
#  1903,
#  193,
#  3045,
#  278,
#  3456,
#  86,
#  48,
#  197,
#  186,
#  305,
#  187,
#  41,
#  94]

# %% [markdown]
# # LSTM FI Top10 list

# %%
lstm_fi = pd.read_csv('./data/method1_entropy.csv')
lstm_fi['abs_score'] = lstm_fi['score'].apply(lambda x:abs(x))
lstm_fi = lstm_fi.sort_values('abs_score', ascending=False)
lstm_feature = lstm_fi.feature[:30].to_list()
lstm_feature
# Out:
# [409606211,
#  74606211,
#  67434504,
#  54817525,
#  10019055302,
#  227194,
#  54858516,
#  74706811,
#  45006701,
#  4003822,
#  228125,
#  50889,
#  63323016501,
#  58177025504,
#  182138167,
#  51479005520,
#  51079007520,
#  51200,
#  406112101,
#  25021011210,
#  63323016101,
#  58468002101,
#  781155613,
#  224270,
#  245021201,
#  51079008620,
#  50383068304,
#  172572810,
#  63323030201,
#  63323038810]

# %%
#COLS에서의 index 추출 (COLS의 index가 곧 3차원데이터 feature의 index이기 때문)

lstm_feature_index = [COLS.index(i) for i in lstm_feature]
lstm_feature_index
# Out:
# [2195,
#  1276,
#  1081,
#  982,
#  2744,
#  383,
#  1011,
#  1306,
#  845,
#  469,
#  392,
#  37,
#  3820,
#  3557,
#  1815,
#  3283,
#  3070,
#  162,
#  2110,
#  2860,
#  3818,
#  3567,
#  2547,
#  301,
#  1915,
#  3076,
#  2988,
#  1722,
#  3841,
#  3852]

# %% [markdown]
# # With RF FI Top10

# %% [markdown]
# ## RF

# %%
path = '/project/LSH/'
X =  np.load(path + 'x_(7727,4068).npy')[:,rf_feature_index]
y = np.load(path + 'y_(7727,1).npy')

idx = list(range(len(X)))
random.shuffle(idx)

i = round(X.shape[0]*0.8)
X_train, y_train = X[idx[:i],:], y[idx[:i]]
X_test, y_test = X[idx[i:],:], y[idx[i:]]

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((6182, 30), (6182,), (1545, 30), (1545,))

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)

pred = model.predict(X_test)

print(f'정확도 : {metrics.accuracy_score(y_test, pred)}')
# Out:
# 정확도 : 0.7080906148867314

# %% [markdown]
# ## LSTM

# %%
import random    
seed_num = 42
random.seed(seed_num)
path = '/project/LSH/'
X = np.load(path + 'x_(7727,10,4068).npy')[:,:,rf_feature_index]
y = np.load(path + 'y_(7727,1).npy')

idx = list(range(len(X)))
random.shuffle(idx)


i = round(X.shape[0]*0.8)
X_train, y_train = X[idx[:i],:,:], y[idx[:i]]
X_test, y_test = X[idx[i:],:,:], y[idx[i:]]

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((6182, 10, 30), (6182,), (1545, 10, 30), (1545,))

# %%
# ---------------------
seed_num = 42 
# ---------------------
tf.random.set_seed(seed_num)

lstm = Sequential()
lstm.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
lstm.add(LSTM(units=128, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(Dropout(0.2))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=32, activation='hard_sigmoid', return_sequences=False))
lstm.add(Dropout(0.2))
lstm.add(Dense(units=1, activation='sigmoid'))

from tensorflow.keras.callbacks import ModelCheckpoint
import os

MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

model_path = MODEL_SAVE_FOLDER_PATH + 'rf_top10_seed42-{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                verbose=1, save_best_only=True)

early_stop = EarlyStopping(monitor='val_acc', patience=50, verbose=1, restore_best_weights=True)
lstm.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
lstm.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  callbacks=[early_stop,cb_checkpoint], shuffle=False)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/500
# 37/37 [==============================] - 6s 74ms/step - loss: 0.6758 - acc: 0.5984 - val_loss: 0.6659 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66589, saving model to ./model/rf_top10_seed42-01-0.6659.hdf5
# Epoch 2/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6728 - acc: 0.6070 - val_loss: 0.6655 - val_acc: 0.6177
#
# Epoch 00002: val_loss improved from 0.66589 to 0.66547, saving model to ./model/rf_top10_seed42-02-0.6655.hdf5
# Epoch 3/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6680 - acc: 0.6091 - val_loss: 0.6442 - val_acc: 0.6177
#
# Epoch 00003: val_loss improved from 0.66547 to 0.64419, saving model to ./model/rf_top10_seed42-03-0.6442.hdf5
# Epoch 4/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6175 - acc: 0.6450 - val_loss: 0.5855 - val_acc: 0.6986
#
# Epoch 00004: val_loss improved from 0.64419 to 0.58553, saving model to ./model/rf_top10_seed42-04-0.5855.hdf5
# Epoch 5/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5778 - acc: 0.7062 - val_loss: 0.5619 - val_acc: 0.7089
#
# Epoch 00005: val_loss improved from 0.58553 to 0.56185, saving model to ./model/rf_top10_seed42-05-0.5619.hdf5
# Epoch 6/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5683 - acc: 0.7148 - val_loss: 0.5549 - val_acc: 0.7180
#
# Epoch 00006: val_loss improved from 0.56185 to 0.55488, saving model to ./model/rf_top10_seed42-06-0.5549.hdf5
# Epoch 7/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5609 - acc: 0.7198 - val_loss: 0.5505 - val_acc: 0.7193
#
# Epoch 00007: val_loss improved from 0.55488 to 0.55053, saving model to ./model/rf_top10_seed42-07-0.5505.hdf5
# Epoch 8/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5567 - acc: 0.7198 - val_loss: 0.5465 - val_acc: 0.7147
#
# Epoch 00008: val_loss improved from 0.55053 to 0.54650, saving model to ./model/rf_top10_seed42-08-0.5465.hdf5
# Epoch 9/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5503 - acc: 0.7215 - val_loss: 0.5449 - val_acc: 0.7186
#
# Epoch 00009: val_loss improved from 0.54650 to 0.54487, saving model to ./model/rf_top10_seed42-09-0.5449.hdf5
# Epoch 10/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5457 - acc: 0.7286 - val_loss: 0.5424 - val_acc: 0.7160
#
# Epoch 00010: val_loss improved from 0.54487 to 0.54238, saving model to ./model/rf_top10_seed42-10-0.5424.hdf5
# Epoch 11/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5452 - acc: 0.7284 - val_loss: 0.5411 - val_acc: 0.7186
#
# Epoch 00011: val_loss improved from 0.54238 to 0.54105, saving model to ./model/rf_top10_seed42-11-0.5411.hdf5
# Epoch 12/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5396 - acc: 0.7353 - val_loss: 0.5403 - val_acc: 0.7173
#
# Epoch 00012: val_loss improved from 0.54105 to 0.54027, saving model to ./model/rf_top10_seed42-12-0.5403.hdf5
# Epoch 13/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5397 - acc: 0.7282 - val_loss: 0.5376 - val_acc: 0.7225
#
# Epoch 00013: val_loss improved from 0.54027 to 0.53758, saving model to ./model/rf_top10_seed42-13-0.5376.hdf5
# Epoch 14/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5342 - acc: 0.7338 - val_loss: 0.5373 - val_acc: 0.7186
#
# Epoch 00014: val_loss improved from 0.53758 to 0.53732, saving model to ./model/rf_top10_seed42-14-0.5373.hdf5
# Epoch 15/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5366 - acc: 0.7349 - val_loss: 0.5356 - val_acc: 0.7245
#
# Epoch 00015: val_loss improved from 0.53732 to 0.53561, saving model to ./model/rf_top10_seed42-15-0.5356.hdf5
# Epoch 16/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5346 - acc: 0.7323 - val_loss: 0.5356 - val_acc: 0.7206
#
# Epoch 00016: val_loss did not improve from 0.53561
# Epoch 17/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5343 - acc: 0.7362 - val_loss: 0.5344 - val_acc: 0.7206
#
# Epoch 00017: val_loss improved from 0.53561 to 0.53442, saving model to ./model/rf_top10_seed42-17-0.5344.hdf5
# Epoch 18/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5295 - acc: 0.7373 - val_loss: 0.5350 - val_acc: 0.7206
#
# Epoch 00018: val_loss did not improve from 0.53442
# Epoch 19/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5304 - acc: 0.7327 - val_loss: 0.5336 - val_acc: 0.7193
#
# Epoch 00019: val_loss improved from 0.53442 to 0.53357, saving model to ./model/rf_top10_seed42-19-0.5336.hdf5
# Epoch 20/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5297 - acc: 0.7360 - val_loss: 0.5321 - val_acc: 0.7219
#
# Epoch 00020: val_loss improved from 0.53357 to 0.53206, saving model to ./model/rf_top10_seed42-20-0.5321.hdf5
# Epoch 21/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5273 - acc: 0.7401 - val_loss: 0.5316 - val_acc: 0.7167
#
# Epoch 00021: val_loss improved from 0.53206 to 0.53163, saving model to ./model/rf_top10_seed42-21-0.5316.hdf5
# Epoch 22/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5264 - acc: 0.7349 - val_loss: 0.5309 - val_acc: 0.7206
#
# Epoch 00022: val_loss improved from 0.53163 to 0.53090, saving model to ./model/rf_top10_seed42-22-0.5309.hdf5
# Epoch 23/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5275 - acc: 0.7384 - val_loss: 0.5315 - val_acc: 0.7193
#
# Epoch 00023: val_loss did not improve from 0.53090
# Epoch 24/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5228 - acc: 0.7414 - val_loss: 0.5310 - val_acc: 0.7186
#
# Epoch 00024: val_loss did not improve from 0.53090
# Epoch 25/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5236 - acc: 0.7401 - val_loss: 0.5296 - val_acc: 0.7199
#
# Epoch 00025: val_loss improved from 0.53090 to 0.52959, saving model to ./model/rf_top10_seed42-25-0.5296.hdf5
# Epoch 26/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5193 - acc: 0.7414 - val_loss: 0.5310 - val_acc: 0.7212
#
# Epoch 00026: val_loss did not improve from 0.52959
# Epoch 27/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5194 - acc: 0.7433 - val_loss: 0.5290 - val_acc: 0.7212
#
# Epoch 00027: val_loss improved from 0.52959 to 0.52905, saving model to ./model/rf_top10_seed42-27-0.5290.hdf5
# Epoch 28/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5174 - acc: 0.7457 - val_loss: 0.5285 - val_acc: 0.7212
#
# Epoch 00028: val_loss improved from 0.52905 to 0.52845, saving model to ./model/rf_top10_seed42-28-0.5285.hdf5
# Epoch 29/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5173 - acc: 0.7429 - val_loss: 0.5277 - val_acc: 0.7206
#
# Epoch 00029: val_loss improved from 0.52845 to 0.52768, saving model to ./model/rf_top10_seed42-29-0.5277.hdf5
# Epoch 30/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5197 - acc: 0.7448 - val_loss: 0.5274 - val_acc: 0.7251
#
# Epoch 00030: val_loss improved from 0.52768 to 0.52736, saving model to ./model/rf_top10_seed42-30-0.5274.hdf5
# Epoch 31/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5150 - acc: 0.7494 - val_loss: 0.5261 - val_acc: 0.7180
#
# Epoch 00031: val_loss improved from 0.52736 to 0.52610, saving model to ./model/rf_top10_seed42-31-0.5261.hdf5
# Epoch 32/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5173 - acc: 0.7431 - val_loss: 0.5267 - val_acc: 0.7245
#
# Epoch 00032: val_loss did not improve from 0.52610
# Epoch 33/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5159 - acc: 0.7433 - val_loss: 0.5252 - val_acc: 0.7219
#
# Epoch 00033: val_loss improved from 0.52610 to 0.52519, saving model to ./model/rf_top10_seed42-33-0.5252.hdf5
# Epoch 34/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5136 - acc: 0.7509 - val_loss: 0.5262 - val_acc: 0.7212
#
# Epoch 00034: val_loss did not improve from 0.52519
# Epoch 35/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5145 - acc: 0.7472 - val_loss: 0.5245 - val_acc: 0.7225
#
# Epoch 00035: val_loss improved from 0.52519 to 0.52453, saving model to ./model/rf_top10_seed42-35-0.5245.hdf5
# Epoch 36/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5124 - acc: 0.7489 - val_loss: 0.5252 - val_acc: 0.7206
#
# Epoch 00036: val_loss did not improve from 0.52453
# Epoch 37/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5078 - acc: 0.7491 - val_loss: 0.5261 - val_acc: 0.7238
#
# Epoch 00037: val_loss did not improve from 0.52453
# Epoch 38/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5096 - acc: 0.7481 - val_loss: 0.5261 - val_acc: 0.7270
#
# Epoch 00038: val_loss did not improve from 0.52453
# Epoch 39/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5085 - acc: 0.7511 - val_loss: 0.5254 - val_acc: 0.7232
#
# Epoch 00039: val_loss did not improve from 0.52453
# Epoch 40/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5066 - acc: 0.7450 - val_loss: 0.5252 - val_acc: 0.7225
#
# Epoch 00040: val_loss did not improve from 0.52453
# Epoch 41/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5082 - acc: 0.7496 - val_loss: 0.5238 - val_acc: 0.7264
#
# Epoch 00041: val_loss improved from 0.52453 to 0.52377, saving model to ./model/rf_top10_seed42-41-0.5238.hdf5
# Epoch 42/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5032 - acc: 0.7494 - val_loss: 0.5240 - val_acc: 0.7264
#
# Epoch 00042: val_loss did not improve from 0.52377
# Epoch 43/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5062 - acc: 0.7485 - val_loss: 0.5248 - val_acc: 0.7251
#
# Epoch 00043: val_loss did not improve from 0.52377
# Epoch 44/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5033 - acc: 0.7522 - val_loss: 0.5244 - val_acc: 0.7264
#
# Epoch 00044: val_loss did not improve from 0.52377
# Epoch 45/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4997 - acc: 0.7571 - val_loss: 0.5262 - val_acc: 0.7251
#
# Epoch 00045: val_loss did not improve from 0.52377
# Epoch 46/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5017 - acc: 0.7528 - val_loss: 0.5257 - val_acc: 0.7257
#
# Epoch 00046: val_loss did not improve from 0.52377
# Epoch 47/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4978 - acc: 0.7556 - val_loss: 0.5258 - val_acc: 0.7290
#
# Epoch 00047: val_loss did not improve from 0.52377
# Epoch 48/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4995 - acc: 0.7524 - val_loss: 0.5251 - val_acc: 0.7270
#
# Epoch 00048: val_loss did not improve from 0.52377
# Epoch 49/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4963 - acc: 0.7556 - val_loss: 0.5275 - val_acc: 0.7257
#
# Epoch 00049: val_loss did not improve from 0.52377
# Epoch 50/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4990 - acc: 0.7554 - val_loss: 0.5292 - val_acc: 0.7238
#
# Epoch 00050: val_loss did not improve from 0.52377
# Epoch 51/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4944 - acc: 0.7547 - val_loss: 0.5286 - val_acc: 0.7238
#
# Epoch 00051: val_loss did not improve from 0.52377
# Epoch 52/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4952 - acc: 0.7554 - val_loss: 0.5266 - val_acc: 0.7264
#
# Epoch 00052: val_loss did not improve from 0.52377
# Epoch 53/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4961 - acc: 0.7528 - val_loss: 0.5259 - val_acc: 0.7277
#
# Epoch 00053: val_loss did not improve from 0.52377
# Epoch 54/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4925 - acc: 0.7535 - val_loss: 0.5264 - val_acc: 0.7270
#
# Epoch 00054: val_loss did not improve from 0.52377
# Epoch 55/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4919 - acc: 0.7485 - val_loss: 0.5277 - val_acc: 0.7290
#
# Epoch 00055: val_loss did not improve from 0.52377
# Epoch 56/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4874 - acc: 0.7573 - val_loss: 0.5281 - val_acc: 0.7245
#
# Epoch 00056: val_loss did not improve from 0.52377
# Epoch 57/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.4902 - acc: 0.7556 - val_loss: 0.5281 - val_acc: 0.7245
#
# Epoch 00057: val_loss did not improve from 0.52377
# Epoch 58/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4883 - acc: 0.7580 - val_loss: 0.5284 - val_acc: 0.7270
#
# Epoch 00058: val_loss did not improve from 0.52377
# Epoch 59/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4894 - acc: 0.7593 - val_loss: 0.5295 - val_acc: 0.7264
#
# Epoch 00059: val_loss did not improve from 0.52377
# Epoch 60/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4848 - acc: 0.7604 - val_loss: 0.5305 - val_acc: 0.7257
#
# Epoch 00060: val_loss did not improve from 0.52377
# Epoch 61/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4871 - acc: 0.7588 - val_loss: 0.5307 - val_acc: 0.7283
#
# Epoch 00061: val_loss did not improve from 0.52377
# Epoch 62/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4886 - acc: 0.7545 - val_loss: 0.5293 - val_acc: 0.7238
#
# Epoch 00062: val_loss did not improve from 0.52377
# Epoch 63/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.4847 - acc: 0.7612 - val_loss: 0.5315 - val_acc: 0.7264
#
# Epoch 00063: val_loss did not improve from 0.52377
# Epoch 64/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.4865 - acc: 0.7595 - val_loss: 0.5292 - val_acc: 0.7238
#
# Epoch 00064: val_loss did not improve from 0.52377
# Epoch 65/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.4816 - acc: 0.7614 - val_loss: 0.5327 - val_acc: 0.7245
#
# Epoch 00065: val_loss did not improve from 0.52377
# Epoch 66/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4792 - acc: 0.7616 - val_loss: 0.5354 - val_acc: 0.7225
#
# Epoch 00066: val_loss did not improve from 0.52377
# Epoch 67/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4787 - acc: 0.7627 - val_loss: 0.5340 - val_acc: 0.7270
#
# Epoch 00067: val_loss did not improve from 0.52377
# Epoch 68/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4781 - acc: 0.7636 - val_loss: 0.5341 - val_acc: 0.7251
#
# Epoch 00068: val_loss did not improve from 0.52377
# Epoch 69/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4801 - acc: 0.7614 - val_loss: 0.5348 - val_acc: 0.7245
#
# Epoch 00069: val_loss did not improve from 0.52377
# Epoch 70/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.4782 - acc: 0.7640 - val_loss: 0.5341 - val_acc: 0.7251
#
# Epoch 00070: val_loss did not improve from 0.52377
# Epoch 71/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4762 - acc: 0.7619 - val_loss: 0.5395 - val_acc: 0.7219
#
# Epoch 00071: val_loss did not improve from 0.52377
# Epoch 72/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4759 - acc: 0.7612 - val_loss: 0.5353 - val_acc: 0.7264
#
# Epoch 00072: val_loss did not improve from 0.52377
# Epoch 73/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.4750 - acc: 0.7636 - val_loss: 0.5375 - val_acc: 0.7257
#
# Epoch 00073: val_loss did not improve from 0.52377
# Epoch 74/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4732 - acc: 0.7636 - val_loss: 0.5379 - val_acc: 0.7219
#
# Epoch 00074: val_loss did not improve from 0.52377
# Epoch 75/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4760 - acc: 0.7703 - val_loss: 0.5377 - val_acc: 0.7245
#
# Epoch 00075: val_loss did not improve from 0.52377
# Epoch 76/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.4711 - acc: 0.7681 - val_loss: 0.5387 - val_acc: 0.7238
#
# Epoch 00076: val_loss did not improve from 0.52377
# Epoch 77/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4705 - acc: 0.7681 - val_loss: 0.5385 - val_acc: 0.7225
#
# Epoch 00077: val_loss did not improve from 0.52377
# Epoch 78/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4734 - acc: 0.7662 - val_loss: 0.5376 - val_acc: 0.7251
#
# Epoch 00078: val_loss did not improve from 0.52377
# Epoch 79/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4695 - acc: 0.7694 - val_loss: 0.5428 - val_acc: 0.7238
#
# Epoch 00079: val_loss did not improve from 0.52377
# Epoch 80/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4709 - acc: 0.7694 - val_loss: 0.5382 - val_acc: 0.7225
#
# Epoch 00080: val_loss did not improve from 0.52377
# Epoch 81/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4716 - acc: 0.7638 - val_loss: 0.5375 - val_acc: 0.7219
#
# Epoch 00081: val_loss did not improve from 0.52377
# Epoch 82/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4681 - acc: 0.7645 - val_loss: 0.5392 - val_acc: 0.7219
#
# Epoch 00082: val_loss did not improve from 0.52377
# Epoch 83/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4642 - acc: 0.7703 - val_loss: 0.5430 - val_acc: 0.7232
#
# Epoch 00083: val_loss did not improve from 0.52377
# Epoch 84/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4667 - acc: 0.7714 - val_loss: 0.5434 - val_acc: 0.7245
#
# Epoch 00084: val_loss did not improve from 0.52377
# Epoch 85/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4638 - acc: 0.7701 - val_loss: 0.5421 - val_acc: 0.7173
#
# Epoch 00085: val_loss did not improve from 0.52377
# Epoch 86/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4635 - acc: 0.7686 - val_loss: 0.5436 - val_acc: 0.7199
#
# Epoch 00086: val_loss did not improve from 0.52377
# Epoch 87/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4652 - acc: 0.7711 - val_loss: 0.5427 - val_acc: 0.7173
#
# Epoch 00087: val_loss did not improve from 0.52377
# Epoch 88/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4632 - acc: 0.7722 - val_loss: 0.5442 - val_acc: 0.7212
#
# Epoch 00088: val_loss did not improve from 0.52377
# Epoch 89/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4607 - acc: 0.7698 - val_loss: 0.5457 - val_acc: 0.7199
#
# Epoch 00089: val_loss did not improve from 0.52377
# Epoch 90/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4606 - acc: 0.7729 - val_loss: 0.5478 - val_acc: 0.7173
#
# Epoch 00090: val_loss did not improve from 0.52377
# Epoch 91/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4581 - acc: 0.7726 - val_loss: 0.5489 - val_acc: 0.7180
#
# Epoch 00091: val_loss did not improve from 0.52377
# Epoch 92/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4610 - acc: 0.7759 - val_loss: 0.5462 - val_acc: 0.7180
#
# Epoch 00092: val_loss did not improve from 0.52377
# Epoch 93/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4610 - acc: 0.7748 - val_loss: 0.5465 - val_acc: 0.7180
#
# Epoch 00093: val_loss did not improve from 0.52377
# Epoch 94/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4592 - acc: 0.7752 - val_loss: 0.5512 - val_acc: 0.7167
#
# Epoch 00094: val_loss did not improve from 0.52377
# Epoch 95/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.4574 - acc: 0.7755 - val_loss: 0.5467 - val_acc: 0.7173
#
# Epoch 00095: val_loss did not improve from 0.52377
# Epoch 96/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.4556 - acc: 0.7722 - val_loss: 0.5493 - val_acc: 0.7212
#
# Epoch 00096: val_loss did not improve from 0.52377
# Epoch 97/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.4531 - acc: 0.7802 - val_loss: 0.5513 - val_acc: 0.7186
# Restoring model weights from the end of the best epoch.
#
# Epoch 00097: val_loss did not improve from 0.52377
# Epoch 00097: early stopping

# %%
from pathlib import Path
paths = sorted(Path(MODEL_SAVE_FOLDER_PATH).iterdir(), key=os.path.getmtime)[-1]
best_model_path = str(paths)
best_model_path
# Out:
# 'model/rf_top10_seed42-41-0.5238.hdf5'

# %%
best_model = keras.models.load_model(best_model_path)
result = 0
for seed in range(0, 50):
    random.seed(seed)

    X = np.load(path + 'x_(7727,10,4068).npy')[:,:,rf_feature_index]
    y = np.load(path + 'y_(7727,1).npy')
    
    idx = list(range(len(x)))
    random.shuffle(idx)
    i = round(X.shape[0]*0.8)
    X_train, y_train = X[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = X[idx[i:],:,:], y[idx[i:]]

    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    result += acc
    print(f'정확도 :{acc}, seed_num = {seed}')
print(f'평균 정확도 : {result/50}')
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 정확도 :0.7300970873786408, seed_num = 0
# 정확도 :0.7385113268608414, seed_num = 1
# 정확도 :0.7449838187702266, seed_num = 2
# 정확도 :0.7385113268608414, seed_num = 3
# 정확도 :0.7469255663430421, seed_num = 4
# 정확도 :0.7521035598705501, seed_num = 5
# 정확도 :0.7475728155339806, seed_num = 6
# 정확도 :0.7378640776699029, seed_num = 7
# 정확도 :0.7611650485436893, seed_num = 8
# 정확도 :0.7404530744336569, seed_num = 9
# 정확도 :0.7462783171521036, seed_num = 10
# 정확도 :0.7585760517799353, seed_num = 11
# 정확도 :0.7495145631067961, seed_num = 12
# 정확도 :0.7423948220064724, seed_num = 13
# 정확도 :0.7488673139158576, seed_num = 14
# 정확도 :0.7501618122977346, seed_num = 15
# 정확도 :0.7631067961165049, seed_num = 16
# 정확도 :0.7436893203883496, seed_num = 17
# 정확도 :0.7495145631067961, seed_num = 18
# 정확도 :0.7423948220064724, seed_num = 19
# 정확도 :0.7365695792880259, seed_num = 20
# 정확도 :0.7352750809061489, seed_num = 21
# 정확도 :0.7359223300970874, seed_num = 22
# 정확도 :0.7417475728155339, seed_num = 23
# 정확도 :0.7288025889967638, seed_num = 24
# 정확도 :0.7404530744336569, seed_num = 25
# 정확도 :0.7300970873786408, seed_num = 26
# 정확도 :0.7339805825242719, seed_num = 27
# 정확도 :0.7469255663430421, seed_num = 28
# 정확도 :0.7411003236245954, seed_num = 29
# 정확도 :0.7682847896440129, seed_num = 30
# 정확도 :0.7378640776699029, seed_num = 31
# 정확도 :0.7294498381877023, seed_num = 32
# 정확도 :0.7456310679611651, seed_num = 33
# 정확도 :0.7566343042071197, seed_num = 34
# 정확도 :0.7423948220064724, seed_num = 35
# 정확도 :0.7585760517799353, seed_num = 36
# 정확도 :0.7572815533980582, seed_num = 37
# 정확도 :0.7385113268608414, seed_num = 38
# 정확도 :0.7423948220064724, seed_num = 39
# 정확도 :0.7411003236245954, seed_num = 40
# 정확도 :0.7346278317152104, seed_num = 41
# 정확도 :0.7449838187702266, seed_num = 42
# 정확도 :0.7514563106796116, seed_num = 43
# 정확도 :0.7281553398058253, seed_num = 44
# 정확도 :0.7521035598705501, seed_num = 45
# 정확도 :0.7404530744336569, seed_num = 46
# 정확도 :0.7527508090614887, seed_num = 47
# 정확도 :0.7631067961165049, seed_num = 48
# 정확도 :0.7436893203883496, seed_num = 49
# 평균 정확도 : 0.7446601941747574

# %% [markdown]
# # With LSTM FI Top10

# %% [markdown]
# ## RF

# %%
path = '/project/LSH/'
X =  np.load(path + 'x_(7727,4068).npy')[:,lstm_feature_index]
y = np.load(path + 'y_(7727,1).npy')

idx = list(range(len(X)))
random.shuffle(idx)

i = round(X.shape[0]*0.8)
X_train, y_train = X[idx[:i],:], y[idx[:i]]
X_test, y_test = X[idx[i:],:], y[idx[i:]]

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((6182, 30), (6182,), (1545, 30), (1545,))

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)

pred = model.predict(X_test)

print(f'정확도 : {metrics.accuracy_score(y_test, pred)}')
# Out:
# 정확도 : 0.6783171521035599

# %% [markdown]
# ## LSTM

# %%
import random    
seed_num = 42
random.seed(seed_num)
path = '/project/LSH/'
X = np.load(path + 'x_(7727,10,4068).npy')[:,:,lstm_feature_index]
y = np.load(path + 'y_(7727,1).npy')

idx = list(range(len(X)))
random.shuffle(idx)


i = round(X.shape[0]*0.8)
X_train, y_train = X[idx[:i],:,:], y[idx[:i]]
X_test, y_test = X[idx[i:],:,:], y[idx[i:]]

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((6182, 10, 30), (6182,), (1545, 10, 30), (1545,))

# %%
# ---------------------
seed_num = 42 
# ---------------------
tf.random.set_seed(seed_num)

lstm = Sequential()
lstm.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2])))
lstm.add(LSTM(units=128, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(Dropout(0.2))
lstm.add(LSTM(units=64, activation='hard_sigmoid', return_sequences=True))
lstm.add(LSTM(units=32, activation='hard_sigmoid', return_sequences=False))
lstm.add(Dropout(0.2))
lstm.add(Dense(units=1, activation='sigmoid'))

from tensorflow.keras.callbacks import ModelCheckpoint
import os

MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

model_path = MODEL_SAVE_FOLDER_PATH + 'lstm_top10_seed42-{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss',
                                verbose=1, save_best_only=True, overwrite=True,)

early_stop = EarlyStopping(monitor='val_acc', patience=50, verbose=1, restore_best_weights=True)
lstm.compile(optimizer= keras.optimizers.Adam(learning_rate = 0.001), loss = "binary_crossentropy", metrics=['acc'])
lstm.fit(X_train, y_train, validation_split=0.25, batch_size=128, epochs=500,  callbacks=[early_stop,cb_checkpoint], shuffle=False)
# Out:
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/500
# 37/37 [==============================] - 5s 70ms/step - loss: 0.6759 - acc: 0.5984 - val_loss: 0.6660 - val_acc: 0.6177
#
# Epoch 00001: val_loss improved from inf to 0.66603, saving model to ./model/lstm_top10_seed42-01-0.6660.hdf5
# Epoch 2/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6732 - acc: 0.6066 - val_loss: 0.6662 - val_acc: 0.6177
#
# Epoch 00002: val_loss did not improve from 0.66603
# Epoch 3/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6740 - acc: 0.6085 - val_loss: 0.6655 - val_acc: 0.6177
#
# Epoch 00003: val_loss improved from 0.66603 to 0.66551, saving model to ./model/lstm_top10_seed42-03-0.6655.hdf5
# Epoch 4/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6711 - acc: 0.6100 - val_loss: 0.6653 - val_acc: 0.6177
#
# Epoch 00004: val_loss improved from 0.66551 to 0.66526, saving model to ./model/lstm_top10_seed42-04-0.6653.hdf5
# Epoch 5/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6706 - acc: 0.6091 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00005: val_loss improved from 0.66526 to 0.66516, saving model to ./model/lstm_top10_seed42-05-0.6652.hdf5
# Epoch 6/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6721 - acc: 0.6113 - val_loss: 0.6651 - val_acc: 0.6177
#
# Epoch 00006: val_loss improved from 0.66516 to 0.66514, saving model to ./model/lstm_top10_seed42-06-0.6651.hdf5
# Epoch 7/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6710 - acc: 0.6111 - val_loss: 0.6651 - val_acc: 0.6177
#
# Epoch 00007: val_loss did not improve from 0.66514
# Epoch 8/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6714 - acc: 0.6111 - val_loss: 0.6652 - val_acc: 0.6177
#
# Epoch 00008: val_loss did not improve from 0.66514
# Epoch 9/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.6702 - acc: 0.6113 - val_loss: 0.6651 - val_acc: 0.6177
#
# Epoch 00009: val_loss improved from 0.66514 to 0.66511, saving model to ./model/lstm_top10_seed42-09-0.6651.hdf5
# Epoch 10/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6699 - acc: 0.6115 - val_loss: 0.6651 - val_acc: 0.6177
#
# Epoch 00010: val_loss improved from 0.66511 to 0.66509, saving model to ./model/lstm_top10_seed42-10-0.6651.hdf5
# Epoch 11/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6697 - acc: 0.6115 - val_loss: 0.6650 - val_acc: 0.6177
#
# Epoch 00011: val_loss improved from 0.66509 to 0.66497, saving model to ./model/lstm_top10_seed42-11-0.6650.hdf5
# Epoch 12/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6692 - acc: 0.6115 - val_loss: 0.6648 - val_acc: 0.6177
#
# Epoch 00012: val_loss improved from 0.66497 to 0.66480, saving model to ./model/lstm_top10_seed42-12-0.6648.hdf5
# Epoch 13/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6689 - acc: 0.6117 - val_loss: 0.6644 - val_acc: 0.6177
#
# Epoch 00013: val_loss improved from 0.66480 to 0.66436, saving model to ./model/lstm_top10_seed42-13-0.6644.hdf5
# Epoch 14/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6643 - acc: 0.6115 - val_loss: 0.6572 - val_acc: 0.6177
#
# Epoch 00014: val_loss improved from 0.66436 to 0.65717, saving model to ./model/lstm_top10_seed42-14-0.6572.hdf5
# Epoch 15/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6490 - acc: 0.6111 - val_loss: 0.6465 - val_acc: 0.6177
#
# Epoch 00015: val_loss improved from 0.65717 to 0.64645, saving model to ./model/lstm_top10_seed42-15-0.6465.hdf5
# Epoch 16/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.6344 - acc: 0.6091 - val_loss: 0.6354 - val_acc: 0.6177
#
# Epoch 00016: val_loss improved from 0.64645 to 0.63543, saving model to ./model/lstm_top10_seed42-16-0.6354.hdf5
# Epoch 17/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.6114 - acc: 0.6333 - val_loss: 0.6254 - val_acc: 0.6397
#
# Epoch 00017: val_loss improved from 0.63543 to 0.62544, saving model to ./model/lstm_top10_seed42-17-0.6254.hdf5
# Epoch 18/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5995 - acc: 0.6428 - val_loss: 0.6288 - val_acc: 0.6358
#
# Epoch 00018: val_loss did not improve from 0.62544
# Epoch 19/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5945 - acc: 0.6400 - val_loss: 0.6258 - val_acc: 0.6391
#
# Epoch 00019: val_loss did not improve from 0.62544
# Epoch 20/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5919 - acc: 0.6421 - val_loss: 0.6273 - val_acc: 0.6397
#
# Epoch 00020: val_loss did not improve from 0.62544
# Epoch 21/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5877 - acc: 0.6497 - val_loss: 0.6213 - val_acc: 0.6475
#
# Epoch 00021: val_loss improved from 0.62544 to 0.62134, saving model to ./model/lstm_top10_seed42-21-0.6213.hdf5
# Epoch 22/500
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5859 - acc: 0.6519 - val_loss: 0.6213 - val_acc: 0.6507
#
# Epoch 00022: val_loss improved from 0.62134 to 0.62131, saving model to ./model/lstm_top10_seed42-22-0.6213.hdf5
# Epoch 23/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5828 - acc: 0.6519 - val_loss: 0.6197 - val_acc: 0.6527
#
# Epoch 00023: val_loss improved from 0.62131 to 0.61969, saving model to ./model/lstm_top10_seed42-23-0.6197.hdf5
# Epoch 24/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5798 - acc: 0.6572 - val_loss: 0.6183 - val_acc: 0.6539
#
# Epoch 00024: val_loss improved from 0.61969 to 0.61831, saving model to ./model/lstm_top10_seed42-24-0.6183.hdf5
# Epoch 25/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5783 - acc: 0.6557 - val_loss: 0.6158 - val_acc: 0.6552
#
# Epoch 00025: val_loss improved from 0.61831 to 0.61576, saving model to ./model/lstm_top10_seed42-25-0.6158.hdf5
# Epoch 26/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5755 - acc: 0.6611 - val_loss: 0.6163 - val_acc: 0.6565
#
# Epoch 00026: val_loss did not improve from 0.61576
# Epoch 27/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5724 - acc: 0.6665 - val_loss: 0.6125 - val_acc: 0.6578
#
# Epoch 00027: val_loss improved from 0.61576 to 0.61251, saving model to ./model/lstm_top10_seed42-27-0.6125.hdf5
# Epoch 28/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5733 - acc: 0.6639 - val_loss: 0.6064 - val_acc: 0.6572
#
# Epoch 00028: val_loss improved from 0.61251 to 0.60641, saving model to ./model/lstm_top10_seed42-28-0.6064.hdf5
# Epoch 29/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5727 - acc: 0.6657 - val_loss: 0.6097 - val_acc: 0.6565
#
# Epoch 00029: val_loss did not improve from 0.60641
# Epoch 30/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5723 - acc: 0.6680 - val_loss: 0.6032 - val_acc: 0.6591
#
# Epoch 00030: val_loss improved from 0.60641 to 0.60318, saving model to ./model/lstm_top10_seed42-30-0.6032.hdf5
# Epoch 31/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5681 - acc: 0.6732 - val_loss: 0.6033 - val_acc: 0.6617
#
# Epoch 00031: val_loss did not improve from 0.60318
# Epoch 32/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5713 - acc: 0.6648 - val_loss: 0.5999 - val_acc: 0.6611
#
# Epoch 00032: val_loss improved from 0.60318 to 0.59993, saving model to ./model/lstm_top10_seed42-32-0.5999.hdf5
# Epoch 33/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5687 - acc: 0.6685 - val_loss: 0.6001 - val_acc: 0.6578
#
# Epoch 00033: val_loss did not improve from 0.59993
# Epoch 34/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5681 - acc: 0.6663 - val_loss: 0.5992 - val_acc: 0.6604
#
# Epoch 00034: val_loss improved from 0.59993 to 0.59917, saving model to ./model/lstm_top10_seed42-34-0.5992.hdf5
# Epoch 35/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5684 - acc: 0.6723 - val_loss: 0.5983 - val_acc: 0.6611
#
# Epoch 00035: val_loss improved from 0.59917 to 0.59829, saving model to ./model/lstm_top10_seed42-35-0.5983.hdf5
# Epoch 36/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5689 - acc: 0.6700 - val_loss: 0.5992 - val_acc: 0.6591
#
# Epoch 00036: val_loss did not improve from 0.59829
# Epoch 37/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5670 - acc: 0.6713 - val_loss: 0.5977 - val_acc: 0.6598
#
# Epoch 00037: val_loss improved from 0.59829 to 0.59766, saving model to ./model/lstm_top10_seed42-37-0.5977.hdf5
# Epoch 38/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5675 - acc: 0.6762 - val_loss: 0.5976 - val_acc: 0.6598
#
# Epoch 00038: val_loss improved from 0.59766 to 0.59765, saving model to ./model/lstm_top10_seed42-38-0.5976.hdf5
# Epoch 39/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5662 - acc: 0.6715 - val_loss: 0.5972 - val_acc: 0.6591
#
# Epoch 00039: val_loss improved from 0.59765 to 0.59722, saving model to ./model/lstm_top10_seed42-39-0.5972.hdf5
# Epoch 40/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5662 - acc: 0.6726 - val_loss: 0.5967 - val_acc: 0.6591
#
# Epoch 00040: val_loss improved from 0.59722 to 0.59673, saving model to ./model/lstm_top10_seed42-40-0.5967.hdf5
# Epoch 41/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5668 - acc: 0.6663 - val_loss: 0.5963 - val_acc: 0.6617
#
# Epoch 00041: val_loss improved from 0.59673 to 0.59628, saving model to ./model/lstm_top10_seed42-41-0.5963.hdf5
# Epoch 42/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5652 - acc: 0.6734 - val_loss: 0.5960 - val_acc: 0.6611
#
# Epoch 00042: val_loss improved from 0.59628 to 0.59601, saving model to ./model/lstm_top10_seed42-42-0.5960.hdf5
# Epoch 43/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5670 - acc: 0.6723 - val_loss: 0.5956 - val_acc: 0.6611
#
# Epoch 00043: val_loss improved from 0.59601 to 0.59565, saving model to ./model/lstm_top10_seed42-43-0.5956.hdf5
# Epoch 44/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5654 - acc: 0.6717 - val_loss: 0.5951 - val_acc: 0.6611
#
# Epoch 00044: val_loss improved from 0.59565 to 0.59510, saving model to ./model/lstm_top10_seed42-44-0.5951.hdf5
# Epoch 45/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5642 - acc: 0.6752 - val_loss: 0.5956 - val_acc: 0.6617
#
# Epoch 00045: val_loss did not improve from 0.59510
# Epoch 46/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5668 - acc: 0.6747 - val_loss: 0.5945 - val_acc: 0.6617
#
# Epoch 00046: val_loss improved from 0.59510 to 0.59447, saving model to ./model/lstm_top10_seed42-46-0.5945.hdf5
# Epoch 47/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5645 - acc: 0.6700 - val_loss: 0.5948 - val_acc: 0.6611
#
# Epoch 00047: val_loss did not improve from 0.59447
# Epoch 48/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5647 - acc: 0.6719 - val_loss: 0.5947 - val_acc: 0.6604
#
# Epoch 00048: val_loss did not improve from 0.59447
# Epoch 49/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5648 - acc: 0.6706 - val_loss: 0.5950 - val_acc: 0.6617
#
# Epoch 00049: val_loss did not improve from 0.59447
# Epoch 50/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5665 - acc: 0.6717 - val_loss: 0.5939 - val_acc: 0.6604
#
# Epoch 00050: val_loss improved from 0.59447 to 0.59388, saving model to ./model/lstm_top10_seed42-50-0.5939.hdf5
# Epoch 51/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5639 - acc: 0.6749 - val_loss: 0.5949 - val_acc: 0.6611
#
# Epoch 00051: val_loss did not improve from 0.59388
# Epoch 52/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5639 - acc: 0.6704 - val_loss: 0.5940 - val_acc: 0.6604
#
# Epoch 00052: val_loss did not improve from 0.59388
# Epoch 53/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5652 - acc: 0.6745 - val_loss: 0.5931 - val_acc: 0.6617
#
# Epoch 00053: val_loss improved from 0.59388 to 0.59314, saving model to ./model/lstm_top10_seed42-53-0.5931.hdf5
# Epoch 54/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5638 - acc: 0.6760 - val_loss: 0.5939 - val_acc: 0.6604
#
# Epoch 00054: val_loss did not improve from 0.59314
# Epoch 55/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5644 - acc: 0.6721 - val_loss: 0.5938 - val_acc: 0.6617
#
# Epoch 00055: val_loss did not improve from 0.59314
# Epoch 56/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5637 - acc: 0.6726 - val_loss: 0.5936 - val_acc: 0.6611
#
# Epoch 00056: val_loss did not improve from 0.59314
# Epoch 57/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5645 - acc: 0.6719 - val_loss: 0.5945 - val_acc: 0.6617
#
# Epoch 00057: val_loss did not improve from 0.59314
# Epoch 58/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5625 - acc: 0.6743 - val_loss: 0.5944 - val_acc: 0.6617
#
# Epoch 00058: val_loss did not improve from 0.59314
# Epoch 59/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5663 - acc: 0.6721 - val_loss: 0.5938 - val_acc: 0.6649
#
# Epoch 00059: val_loss did not improve from 0.59314
# Epoch 60/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5641 - acc: 0.6754 - val_loss: 0.5942 - val_acc: 0.6649
#
# Epoch 00060: val_loss did not improve from 0.59314
# Epoch 61/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5640 - acc: 0.6728 - val_loss: 0.5962 - val_acc: 0.6649
#
# Epoch 00061: val_loss did not improve from 0.59314
# Epoch 62/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5672 - acc: 0.6743 - val_loss: 0.5970 - val_acc: 0.6636
#
# Epoch 00062: val_loss did not improve from 0.59314
# Epoch 63/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5654 - acc: 0.6717 - val_loss: 0.5995 - val_acc: 0.6604
#
# Epoch 00063: val_loss did not improve from 0.59314
# Epoch 64/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5676 - acc: 0.6648 - val_loss: 0.5999 - val_acc: 0.6598
#
# Epoch 00064: val_loss did not improve from 0.59314
# Epoch 65/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5654 - acc: 0.6700 - val_loss: 0.6035 - val_acc: 0.6630
#
# Epoch 00065: val_loss did not improve from 0.59314
# Epoch 66/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5648 - acc: 0.6693 - val_loss: 0.6039 - val_acc: 0.6591
#
# Epoch 00066: val_loss did not improve from 0.59314
# Epoch 67/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5643 - acc: 0.6713 - val_loss: 0.6030 - val_acc: 0.6624
#
# Epoch 00067: val_loss did not improve from 0.59314
# Epoch 68/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5645 - acc: 0.6704 - val_loss: 0.6032 - val_acc: 0.6624
#
# Epoch 00068: val_loss did not improve from 0.59314
# Epoch 69/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5639 - acc: 0.6719 - val_loss: 0.5989 - val_acc: 0.6636
#
# Epoch 00069: val_loss did not improve from 0.59314
# Epoch 70/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5637 - acc: 0.6736 - val_loss: 0.5979 - val_acc: 0.6624
#
# Epoch 00070: val_loss did not improve from 0.59314
# Epoch 71/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5619 - acc: 0.6747 - val_loss: 0.6003 - val_acc: 0.6630
#
# Epoch 00071: val_loss did not improve from 0.59314
# Epoch 72/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5643 - acc: 0.6706 - val_loss: 0.6001 - val_acc: 0.6630
#
# Epoch 00072: val_loss did not improve from 0.59314
# Epoch 73/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5643 - acc: 0.6682 - val_loss: 0.6005 - val_acc: 0.6624
#
# Epoch 00073: val_loss did not improve from 0.59314
# Epoch 74/500
# 37/37 [==============================] - 2s 61ms/step - loss: 0.5630 - acc: 0.6743 - val_loss: 0.5981 - val_acc: 0.6643
#
# Epoch 00074: val_loss did not improve from 0.59314
# Epoch 75/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5632 - acc: 0.6749 - val_loss: 0.5968 - val_acc: 0.6624
#
# Epoch 00075: val_loss did not improve from 0.59314
# Epoch 76/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5631 - acc: 0.6747 - val_loss: 0.5999 - val_acc: 0.6643
#
# Epoch 00076: val_loss did not improve from 0.59314
# Epoch 77/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5635 - acc: 0.6700 - val_loss: 0.5976 - val_acc: 0.6643
#
# Epoch 00077: val_loss did not improve from 0.59314
# Epoch 78/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5622 - acc: 0.6739 - val_loss: 0.5984 - val_acc: 0.6624
#
# Epoch 00078: val_loss did not improve from 0.59314
# Epoch 79/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5608 - acc: 0.6721 - val_loss: 0.5975 - val_acc: 0.6624
#
# Epoch 00079: val_loss did not improve from 0.59314
# Epoch 80/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5627 - acc: 0.6723 - val_loss: 0.5997 - val_acc: 0.6643
#
# Epoch 00080: val_loss did not improve from 0.59314
# Epoch 81/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5631 - acc: 0.6704 - val_loss: 0.5953 - val_acc: 0.6649
#
# Epoch 00081: val_loss did not improve from 0.59314
# Epoch 82/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5609 - acc: 0.6756 - val_loss: 0.5986 - val_acc: 0.6624
#
# Epoch 00082: val_loss did not improve from 0.59314
# Epoch 83/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5594 - acc: 0.6743 - val_loss: 0.5991 - val_acc: 0.6636
#
# Epoch 00083: val_loss did not improve from 0.59314
# Epoch 84/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5621 - acc: 0.6713 - val_loss: 0.5971 - val_acc: 0.6624
#
# Epoch 00084: val_loss did not improve from 0.59314
# Epoch 85/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5620 - acc: 0.6756 - val_loss: 0.5999 - val_acc: 0.6624
#
# Epoch 00085: val_loss did not improve from 0.59314
# Epoch 86/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5598 - acc: 0.6762 - val_loss: 0.5986 - val_acc: 0.6624
#
# Epoch 00086: val_loss did not improve from 0.59314
# Epoch 87/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5599 - acc: 0.6754 - val_loss: 0.5970 - val_acc: 0.6643
#
# Epoch 00087: val_loss did not improve from 0.59314
# Epoch 88/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5597 - acc: 0.6756 - val_loss: 0.5998 - val_acc: 0.6624
#
# Epoch 00088: val_loss did not improve from 0.59314
# Epoch 89/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5597 - acc: 0.6721 - val_loss: 0.5990 - val_acc: 0.6630
#
# Epoch 00089: val_loss did not improve from 0.59314
# Epoch 90/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5610 - acc: 0.6723 - val_loss: 0.5971 - val_acc: 0.6649
#
# Epoch 00090: val_loss did not improve from 0.59314
# Epoch 91/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5588 - acc: 0.6771 - val_loss: 0.5966 - val_acc: 0.6649
#
# Epoch 00091: val_loss did not improve from 0.59314
# Epoch 92/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5595 - acc: 0.6752 - val_loss: 0.5984 - val_acc: 0.6624
#
# Epoch 00092: val_loss did not improve from 0.59314
# Epoch 93/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5613 - acc: 0.6752 - val_loss: 0.5988 - val_acc: 0.6630
#
# Epoch 00093: val_loss did not improve from 0.59314
# Epoch 94/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5607 - acc: 0.6747 - val_loss: 0.5974 - val_acc: 0.6624
#
# Epoch 00094: val_loss did not improve from 0.59314
# Epoch 95/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5599 - acc: 0.6764 - val_loss: 0.5989 - val_acc: 0.6643
#
# Epoch 00095: val_loss did not improve from 0.59314
# Epoch 96/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5599 - acc: 0.6756 - val_loss: 0.5961 - val_acc: 0.6649
#
# Epoch 00096: val_loss did not improve from 0.59314
# Epoch 97/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5575 - acc: 0.6762 - val_loss: 0.5973 - val_acc: 0.6643
#
# Epoch 00097: val_loss did not improve from 0.59314
# Epoch 98/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5587 - acc: 0.6777 - val_loss: 0.5973 - val_acc: 0.6643
#
# Epoch 00098: val_loss did not improve from 0.59314
# Epoch 99/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5578 - acc: 0.6760 - val_loss: 0.5980 - val_acc: 0.6643
#
# Epoch 00099: val_loss did not improve from 0.59314
# Epoch 100/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5594 - acc: 0.6771 - val_loss: 0.5991 - val_acc: 0.6630
#
# Epoch 00100: val_loss did not improve from 0.59314
# Epoch 101/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5583 - acc: 0.6782 - val_loss: 0.6002 - val_acc: 0.6636
#
# Epoch 00101: val_loss did not improve from 0.59314
# Epoch 102/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5592 - acc: 0.6788 - val_loss: 0.5966 - val_acc: 0.6649
#
# Epoch 00102: val_loss did not improve from 0.59314
# Epoch 103/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5576 - acc: 0.6780 - val_loss: 0.6008 - val_acc: 0.6630
#
# Epoch 00103: val_loss did not improve from 0.59314
# Epoch 104/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5609 - acc: 0.6760 - val_loss: 0.5992 - val_acc: 0.6636
#
# Epoch 00104: val_loss did not improve from 0.59314
# Epoch 105/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5587 - acc: 0.6762 - val_loss: 0.5984 - val_acc: 0.6643
#
# Epoch 00105: val_loss did not improve from 0.59314
# Epoch 106/500
# 37/37 [==============================] - 2s 62ms/step - loss: 0.5586 - acc: 0.6752 - val_loss: 0.5985 - val_acc: 0.6643
#
# Epoch 00106: val_loss did not improve from 0.59314
# Epoch 107/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5575 - acc: 0.6775 - val_loss: 0.5989 - val_acc: 0.6643
#
# Epoch 00107: val_loss did not improve from 0.59314
# Epoch 108/500
# 37/37 [==============================] - 2s 63ms/step - loss: 0.5570 - acc: 0.6760 - val_loss: 0.5983 - val_acc: 0.6643
#
# Epoch 00108: val_loss did not improve from 0.59314
# Epoch 109/500
# 37/37 [==============================] - 2s 64ms/step - loss: 0.5574 - acc: 0.6767 - val_loss: 0.5966 - val_acc: 0.6643
# Restoring model weights from the end of the best epoch.
#
# Epoch 00109: val_loss did not improve from 0.59314
# Epoch 00109: early stopping

# %%
from pathlib import Path
paths = sorted(Path(MODEL_SAVE_FOLDER_PATH).iterdir(), key=os.path.getmtime)[-1]
best_model_path = str(paths)
best_model_path
# Out:
# 'model/lstm_top10_seed42-53-0.5931.hdf5'

# %%
# best_model = keras.models.load_model('./model/lstm_top10_seed42-84-0.6057.hdf5')
best_model = keras.models.load_model(best_model_path)
result = 0
for seed in range(0, 50):
    random.seed(seed)
    X = np.load(path + 'x_(7727,10,4068).npy')[:,:,lstm_feature_index]
    y = np.load(path + 'y_(7727,1).npy')
    
    idx = list(range(len(x)))
    random.shuffle(idx)
    i = round(X.shape[0]*0.8)
    X_train, y_train = X[idx[:i],:,:], y[idx[:i]]
    X_test, y_test = X[idx[i:],:,:], y[idx[i:]]

    pred = best_model.predict(X_test)
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    acc = metrics.accuracy_score(y_test, pred)
    result += acc
    print(f'정확도 :{acc}, seed_num = {seed}')
print(f'평균 정확도 : {result/50}')
# Out:
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 정확도 :0.6705501618122978, seed_num = 0
# 정확도 :0.655663430420712, seed_num = 1
# 정확도 :0.656957928802589, seed_num = 2
# 정확도 :0.6601941747572816, seed_num = 3
# 정확도 :0.6757281553398058, seed_num = 4
# 정확도 :0.6647249190938511, seed_num = 5
# 정확도 :0.6718446601941748, seed_num = 6
# 정확도 :0.6459546925566343, seed_num = 7
# 정확도 :0.6679611650485436, seed_num = 8
# 정확도 :0.6621359223300971, seed_num = 9
# 정확도 :0.6427184466019418, seed_num = 10
# 정확도 :0.6809061488673139, seed_num = 11
# 정확도 :0.6634304207119741, seed_num = 12
# 정확도 :0.6530744336569579, seed_num = 13
# 정확도 :0.6601941747572816, seed_num = 14
# 정확도 :0.683495145631068, seed_num = 15
# 정확도 :0.6906148867313916, seed_num = 16
# 정확도 :0.6614886731391586, seed_num = 17
# 정확도 :0.6673139158576051, seed_num = 18
# 정확도 :0.6595469255663431, seed_num = 19
# 정확도 :0.684789644012945, seed_num = 20
# 정확도 :0.6666666666666666, seed_num = 21
# 정확도 :0.654368932038835, seed_num = 22
# 정확도 :0.6724919093851133, seed_num = 23
# 정확도 :0.6705501618122978, seed_num = 24
# 정확도 :0.6686084142394823, seed_num = 25
# 정확도 :0.6530744336569579, seed_num = 26
# 정확도 :0.6724919093851133, seed_num = 27
# 정확도 :0.6601941747572816, seed_num = 28
# 정확도 :0.6640776699029126, seed_num = 29
# 정확도 :0.6731391585760518, seed_num = 30
# 정확도 :0.6576051779935275, seed_num = 31
# 정확도 :0.6679611650485436, seed_num = 32
# 정확도 :0.6770226537216828, seed_num = 33
# 정확도 :0.6640776699029126, seed_num = 34
# 정확도 :0.6776699029126214, seed_num = 35
# 정확도 :0.6634304207119741, seed_num = 36
# 정확도 :0.6660194174757281, seed_num = 37
# 정확도 :0.6511326860841424, seed_num = 38
# 정확도 :0.6867313915857605, seed_num = 39
# 정확도 :0.6563106796116505, seed_num = 40
# 정확도 :0.6640776699029126, seed_num = 41
# 정확도 :0.6537216828478964, seed_num = 42
# 정확도 :0.6576051779935275, seed_num = 43
# 정확도 :0.6504854368932039, seed_num = 44
# 정확도 :0.6789644012944984, seed_num = 45
# 정확도 :0.6666666666666666, seed_num = 46
# 정확도 :0.6802588996763754, seed_num = 47
# 정확도 :0.6906148867313916, seed_num = 48
# 정확도 :0.6679611650485436, seed_num = 49
# 평균 정확도 : 0.6662653721682846
